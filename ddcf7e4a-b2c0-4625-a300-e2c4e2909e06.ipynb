# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# Привет, меня зовут Александр Куимов. Я буду ревьюером твоего проекта. Ты можешь обращаться ко мне на "ты"😏 Надеюсь, тебя также не смутит, если я буду обращаться к тебе на "ты", но если это неудобно, обязательно скажи об этом!
#
# **Пожалуйста, не перемещай, не изменяй и не удаляй мои комментарии**, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Прошу реагировать на все мои комментарии, по которым ты вносишь правки в проект, своими комментариями по шаблону, показанному чуть ниже. На каждое мое замечание нужно отвечать комментарием студента в маркдаун ячейке **ниже моей. Это нужно, чтобы не создавалась путаница**.😉
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>же лтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В случае, если решение на отдельном шаге является полностью правильным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> В случае, когда решение на отдельном шаге станет еще лучше, если внести небольшие коррективы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#  В случае, когда решение на отдельном шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
# </div>
#
#
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> В такой цветовой ячейке - образце я прошу тебя оставлять твои комментарии. **Обязательно сохрани в нем заголовок "Комментарий студента" в каждой твоей ячейке**. Если исправляешь проект во второй раз и далее, не забывай пожалуйста указывать номер итерации, например, "Комментарий студента 2". У меня к этому моменту уже появится нумерация в моих комментариях.
# </div>
#
# <br/>
#
# Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие и дам тебе возможность самому найти и исправить ее. На реальной работе твой руководитель будет поступать также, и я пытаюсь подготовить тебя именно к работе датасаентистом. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку!🤓
#
#    **Если у тебя будут возникают какие-то сложности, связанные с выполнением этого проекта**, то я смогу отвечать тебе на вопросы только в ходе ревью до 24 часов на основании соглашения об уровне услуг SLA (это может быть любое время суток, даже ночью), и к сожалению, каждые из таких ревью расходуют доступные иттерации (их всего 6).
# Лучшее решение в подобных случаях - обратиться за помощью к преподавателю по проектам в треде для получения оперативных консультаций. На всякий случай акцентирую, что преподаватель отвечает в тредах, а в личку не отвечает. В редких случаях может возникнуть ситуация, когда преподаватель не ответил вовремя, в таком случае рекомендую связаться с куратором для оперативного решения вопроса.
#
#    **Если у тебя будут возникают вопросы, которые не касаются проекта и моих комментариев в нем**, а касаются теории и спринта, то я смогу кратко тебе ответить, а подробнее на вопрос тебе ответит преподаватель и по запросу сможет подобрать материал адекватный текущему прогрессу курса (только нужно написать ему в тред) 🤓

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-и-подготовка-данных" data-toc-modified-id="Загрузка-и-подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка и подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Загрузка-данных-и-первичная-оценка" data-toc-modified-id="Загрузка-данных-и-первичная-оценка-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Загрузка данных и первичная оценка</a></span></li></ul></li><li><span><a href="#Анализ" data-toc-modified-id="Анализ-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ</a></span></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Подготовка данных</a></span></li><li><span><a href="#Обучение" data-toc-modified-id="Обучение-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Обучение</a></span><ul class="toc-item"><li><span><a href="#LinearRegression" data-toc-modified-id="LinearRegression-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>LinearRegression</a></span></li><li><span><a href="#RandomForestRegressor" data-toc-modified-id="RandomForestRegressor-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>RandomForestRegressor</a></span></li><li><span><a href="#CatBoostRegressor" data-toc-modified-id="CatBoostRegressor-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>CatBoostRegressor</a></span></li><li><span><a href="#Анализ-моделей" data-toc-modified-id="Анализ-моделей-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Анализ моделей</a></span></li></ul></li><li><span><a href="#Тестирование" data-toc-modified-id="Тестирование-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Тестирование</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Выводы</a></span></li><li><span><a href="#Чек-лист-проверки" data-toc-modified-id="Чек-лист-проверки-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Чек-лист проверки</a></span></li></ul></div>

# %% [markdown]
# #  Прогнозирование заказов такси

# %% [markdown]
# Компания «Чётенькое такси» собрала исторические данные о заказах такси в аэропортах. Чтобы привлекать больше водителей в период пиковой нагрузки, нужно спрогнозировать количество заказов такси на следующий час. Постройте модель для такого предсказания.
#
# Значение метрики *RMSE* на тестовой выборке должно быть не больше 48.
#
# Вам нужно:
#
# 1. Загрузить данные и выполнить их ресемплирование по одному часу.
# 2. Проанализировать данные.
# 3. Обучить разные модели с различными гиперпараметрами. Сделать тестовую выборку размером 10% от исходных данных.
# 4. Проверить данные на тестовой выборке и сделать выводы.
#
#
# Данные лежат в файле `taxi.csv`. Количество заказов находится в столбце `num_orders` (от англ. *number of orders*, «число заказов»).

# %% [markdown]
# **Цель исследования:** построить модель для прогноза количества заказов такси на следующий час.

# %% [markdown]
# **План исследования:**
#
# - загрузить и изучить данные
# - произвети ресемплирование по часу
# - сделать анализ данных
# - подготовить данные для модлеей МЛ
# - обучить несколько моделей
# - выбрать лучшую и проверить на тесте

# %% [markdown]
# **Критерии:**
#
# - значение метрики RMSE на тестовой выборке должно быть не больше 48

# %% [markdown]
# **Ключевой признак:** num_orders

# %% [markdown]
# ## Загрузка и подготовка данных

# %%
# !pip install -q phik
# !pip install -q shap
# !pip install -q lightgbm
# !pip install -q catboost
# !pip install -Uq scikit-learn
# !pip install -q statsmodels

# %%
# базовые библиотеки для работы с данными
import pandas as pd
import numpy as np

# библиотеки для визуализации
import matplotlib.pyplot as plt
import seaborn as sns

# статистические библиотеки
from phik import phik_matrix
from phik.report import plot_correlation_matrix

# основные инструменты sklearn
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split, TimeSeriesSplit
from statsmodels.tsa.seasonal import seasonal_decompose

# модели машинного обучения
from catboost import CatBoostRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# интерпретация модели
import shap

# системные библиотеки
import warnings
from warnings import simplefilter
import os

# %%
# дополнительные настройки 
pd.options.mode.chained_assignment = None
warnings.filterwarnings("ignore")
simplefilter(action='ignore', category=FutureWarning)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.options.mode.chained_assignment = None

# %%
RANDOM_STATE = 42
TEST_SIZE = 0.1

# %% [markdown]
# ### Загрузка данных и первичная оценка

# %%
local_path = {
    'taxi': '/datasets/taxi.csv'
}

url_path = {
    'taxi': 'https://code.s3.yandex.net/datasets/taxi.csv'
}

# загрузка данных заказов такси
if os.path.exists(local_path['taxi']):
    df_taxi = pd.read_csv(local_path['taxi'], index_col=[0], parse_dates=[0])
elif requests.get(url_paths['taxi']).status_code == 200:
    df_taxi = pd.read_csv(url_path['taxi'], index_col=[0], parse_dates=[0])
else:
    print('Ошибка загрузки данных заказов такси')

# %%
# функция вывода информации о датасете
def df_info(df):
    display(df.info())
    print('-----------')
    display(df.head())
    print('-----------')
    display(df.describe().T)
    print('-----------')
    cols = df.columns
    for col in cols:
        print(df[col].unique())
    print('-----------')
    print('Кол-во пропусков:\n', df.isna().sum())

# %%
df_info(df_taxi)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 26496 entries, 2018-03-01 00:00:00 to 2018-08-31 23:50:00
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   num_orders  26496 non-null  int64
# dtypes: int64(1)
# memory usage: 414.0 KB
# None
# -----------
#                      num_orders
# datetime
# 2018-03-01 00:00:00           9
# 2018-03-01 00:10:00          14
# 2018-03-01 00:20:00          28
# 2018-03-01 00:30:00          20
# 2018-03-01 00:40:00          32
# -----------
#               count       mean      std  min  25%   50%   75%    max
# num_orders  26496.0  14.070463  9.21133  0.0  8.0  13.0  19.0  119.0
# -----------
# [  9  14  28  20  32  21   7   5  17  12  19  25  22   8   6   4  10  13
#    2   3   0   1  11  15  16  23  18  33  24  26  30  38  34  42  31  27
#   36  29  35  56  37  40  39  45  49  58  68  43  53  44  41  52  46  57
# ...

# %% [markdown]
# - в данных представлена информация о 26496 поездках
# - данные от 1 марта 2018 года (0:00) по 31 августа 2018 года (23:50)
# - пропущенных значений нет
# - типы данных в норме

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# С данными познакомились, проведен первичный аналитический осмотр!) Отлично, что ниже проведено ресемплирование с использованием суммы. Полученная информация поможет нам в дальнейшем с предобработкой данных

# %% [markdown]
# ## Анализ

# %% [markdown]
# **Сделаем проверку на монотонность данных, это нужно чтобы:**
# - выявить тренды, определить общий спад или рост
# - обнаружить аномалии, поскольку подразумевается непрерывность поступления заказов
# - обеспечение корректности работы моделей МЛ

# %%
df_taxi.index.is_monotonic_increasing
# Out:
# True

# %%
# ресэмплинг
df_taxi = df_taxi.resample('1H').sum()

# %%
plt.figure(figsize=(15, 5))
plt.style.use('ggplot')

plt.plot(df_taxi['num_orders'], label='Количество заказов', color='#5470C6', linewidth=1.5)
plt.plot(df_taxi['num_orders'].rolling(50).mean(), label='Скользящее среднее (50)', 
         color='#EA5252', linewidth=2)
plt.plot(df_taxi['num_orders'].rolling(50).std(), label='Стандартное отклонение (50)', 
         color='#91CC75', linewidth=2)

plt.title('Анализ количества заказов такси', fontsize=16)
plt.xlabel('Дата/время', fontsize=12)
plt.ylabel('Количество', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(fontsize=12)

plt.tight_layout()
plt.show()

# %%
def plotting(data, title, color='#5470C6'):
    plt.figure(figsize=(15, 5))
    plt.style.use('ggplot')
    
    sns.lineplot(data=data, color=color, linewidth=2)
    
    plt.title(title, fontsize=16)
    plt.xlabel('Дата', fontsize=12)
    plt.ylabel('Значение', fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.tight_layout()
    
    plt.show()

# %%
# декомпозиция данных для выделения тренда, сезонности , остатков
decomposed_taxi = seasonal_decompose(df_taxi['num_orders'])

# %%
# график тренда
plotting(decomposed_taxi.trend, 'Тренд в количестве заказов такси', color='#5470C6')

# %% [markdown]
# Происходит постепенный рост к августу, возможно связано с сезоном отпусков

# %%
# график сезонности
plotting(decomposed_taxi.seasonal, 'Сезонность в заказах такси', color='#5470C6')

# %%
plotting(decomposed_taxi.seasonal['2018-03-01':'2018-03-07'], 
         'Заказы такси (за одну неделю)', color='#5470C6')

# %%
plotting(decomposed_taxi.seasonal['2018-03-01':'2018-03-02'], 
         'Заказы по часам (за двое суток)', color='#5470C6')

# %%
# график остатков (шумов)
plotting(decomposed_taxi.resid, 'Остатки (случайная составляющая) в заказах такси', color='#91CC75')

# %% [markdown]
# **Анализ графиков:**
#
# **Дневной цикл заказов**
# - пиковые часы: максимальный спрос приходится на полночь (около 00:00), когда значения достигают +60
# - минимальный спрос: явно выраженный спад активности в ранние утренние часы (около 06:00), значения опускаются до -60
# - наблюдается постепенное увеличение количества заказов в вечернее время (с 16:00), формирующее второй менее выраженный пик
#
# **Недельная динамика**
# - стабильность паттерна: ежедневный цикл практически идентичен на протяжении всей недели
# - отсутствие различий между буднями и выходными: суточный ритм сохраняется независимо от дня недели
# - устойчивость амплитуды: колебания между пиковыми и минимальными значениями остаются в диапазоне от -60 до +60 всю неделю
#
# **Долгосрочные наблюдения**
# - сезонная устойчивость: паттерн суточной активности не меняется на протяжении всего периода наблюдений (март-сентябрь)
# - независимость от месяца: амплитуда и характер суточных колебаний не демонстрируют зависимости от сезона года
#
# **Остатки**
# - базовый диапазон колебаний: большая часть остатков находится в пределах от -50 до +50
# - остатки демонстрируют относительную стационарность в первой части периода наблюдений
# - отсутствие явных паттернов: в основной массе данных нет видимой структуры, что подтверждает качество декомпозиции
# - экстремальные значения в августе: наблюдаются значительные положительные выбросы, достигающие +250
# - положительные выбросы (неожиданные всплески спроса) существенно превышают по амплитуде отрицательные
# - к концу анализируемого периода (август-сентябрь) размах колебаний заметно увеличивается

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# Декомпозиция сделана верно. Хорошо, что сезонность была визуализирована на более коротком интервале)

# %% [markdown]
# ## Подготовка данных

# %%
def new_features(df, max_lag=10, rolling_mean_size=24, add_date_features=True):

    if not isinstance(df.index, pd.DatetimeIndex):
        raise ValueError("Индекс датафрейма должен быть DatetimeIndex")
    
    data_copy = df.copy()
    target_col = 'num_orders'
    
    # добавление признаков
    if add_date_features:
        # синус и косинус для улучшения представления цикличности, 23 и 0 находятся рядом, а не максимально далеки
        data_copy['month'] = data_copy.index.month
        data_copy['month_sin'] = np.sin(2 * np.pi * data_copy.index.month / 12)
        data_copy['month_cos'] = np.cos(2 * np.pi * data_copy.index.month / 12)
        
        data_copy['day'] = data_copy.index.day
        data_copy['dayofweek'] = data_copy.index.dayofweek
        data_copy['dayofweek_sin'] = np.sin(2 * np.pi * data_copy.index.dayofweek / 7)
        data_copy['dayofweek_cos'] = np.cos(2 * np.pi * data_copy.index.dayofweek / 7)
        
        data_copy['hour'] = data_copy.index.hour
        data_copy['hour_sin'] = np.sin(2 * np.pi * data_copy.index.hour / 24)
        data_copy['hour_cos'] = np.cos(2 * np.pi * data_copy.index.hour / 24)
        
        data_copy['is_weekend'] = data_copy.index.dayofweek.isin([5, 6]).astype(int)
    
    lags = [f'lag_{i}' for i in range(1, max_lag + 1)]
    for i, lag in enumerate(range(1, max_lag + 1)):
        data_copy[f'lag_{lag}'] = data_copy[target_col].shift(lag)
    
    data_copy['rolling_mean'] = data_copy[target_col].shift().rolling(rolling_mean_size).mean()
    data_copy['rolling_std'] = data_copy[target_col].shift().rolling(rolling_mean_size).std()
    data_copy['rolling_median'] = data_copy[target_col].shift().rolling(rolling_mean_size).median()
    
    data_copy.dropna(inplace=True)
    return data_copy

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# Отлично, что написана функция, которая возвращает новый датафрейм, а не изменяет глобальную переменную

# %%
data_ml = new_features(df_taxi, max_lag=180, rolling_mean_size=180)

print(f'Размер оригинального датасета: {df_taxi.shape}')
print(f'Размер обновленного датасета: {data_ml.shape}')
# Out:
# Размер оригинального датасета: (4416, 1)
# Размер обновленного датасета: (4236, 195)

# %%
TEST_SIZE = 0.1  # 10% данных для тестирования

X = data_ml.drop('num_orders', axis=1)
y = data_ml['num_orders']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, shuffle=False, test_size=TEST_SIZE)

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# Хорошо, что деление происходит последовательно по времени

# %%
print('='*50)
print('ИНФОРМАЦИЯ О ВЫБОРКАХ')
print('='*50)

print(f'Размер обучающей выборки: {X_train.shape[0]} записей, {X_train.shape[1]} признаков')
print(f'Размер тестовой выборки: {X_test.shape[0]} записей, {X_test.shape[1]} признаков')
print()

print('ВРЕМЕННЫЕ ДИАПАЗОНЫ:')
print('-'*50)
print(f'Обучающая выборка: с {X_train.index.min().strftime("%d.%m.%Y %H:%M")} по {X_train.index.max().strftime("%d.%m.%Y %H:%M")}')
print(f'Тестовая выборка:  с {X_test.index.min().strftime("%d.%m.%Y %H:%M")} по {X_test.index.max().strftime("%d.%m.%Y %H:%M")}')
print()

time_diff = X_test.index.min() - X_train.index.max()
print('ПРОВЕРКА КОРРЕКТНОСТИ:')
print('-'*50)
print(f'Разрыв между выборками: {time_diff}')
if time_diff.total_seconds() > 0:
    print("Тестовая выборка идет ПОСЛЕ обучающей - разбиение корректно")
else:
    print("ВНИМАНИЕ! Возможна утечка данных: тестовая выборка перекрывается с обучающей")
# Out:
# ...
# ИНФОРМАЦИЯ О ВЫБОРКАХ
# ...
# Размер обучающей выборки: 3812 записей, 194 признаков
# Размер тестовой выборки: 424 записей, 194 признаков
#
# ВРЕМЕННЫЕ ДИАПАЗОНЫ:
# --------------------------------------------------
# Обучающая выборка: с 08.03.2018 12:00 по 14.08.2018 07:00
# Тестовая выборка:  с 14.08.2018 08:00 по 31.08.2018 23:00
#
# ПРОВЕРКА КОРРЕКТНОСТИ:
# --------------------------------------------------
# Разрыв между выборками: 0 days 01:00:00
# Тестовая выборка идет ПОСЛЕ обучающей - разбиение корректно

# %% [markdown]
# ## Обучение

# %% [markdown]
# ### LinearRegression

# %%
models = []
lin_reg = LinearRegression()

# %%
# %%time
lin_reg.fit(X_train, y_train)
# Out:
# CPU times: user 226 ms, sys: 245 ms, total: 471 ms
# Wall time: 400 ms
# LinearRegression()

# %%
cv = TimeSeriesSplit(n_splits=5)

# %%
scores = cross_val_score(
    lin_reg, 
    X_train, 
    y_train, 
    cv=cv, 
    n_jobs=-1, 
    scoring='neg_root_mean_squared_error'
)
rmse_cv_lin_reg = (-1) * np.mean(scores)

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# Отлично, что применяется TimeSeriesSplit, а не простой сплиттер

# %%
y_pred_lin_reg = lin_reg.predict(X_train)
rmse_train_lin_reg = np.sqrt(mean_squared_error(y_train, y_pred_lin_reg))

# %%
print(f'RMSE LinearRegression на кросс-валидации: {rmse_cv_lin_reg:.4f}')
print(f'RMSE LinearRegression на тренировочной выборке: {rmse_train_lin_reg:.4f}')
print('-'*50)

# Сохраняем модель и метрики в список
models.append([lin_reg, rmse_cv_lin_reg, rmse_train_lin_reg])
# Out:
# RMSE LinearRegression на кросс-валидации: 23.2901
# RMSE LinearRegression на тренировочной выборке: 20.1974
# --------------------------------------------------

# %% [markdown]
# ### RandomForestRegressor

# %%
rf_model = RandomForestRegressor(random_state=RANDOM_STATE)

# %%
rf_params = {
    'n_estimators': range(50, 100, 10),
    'max_depth': range(5, 20, 5),
}

# %%
rf_grid = RandomizedSearchCV(
    rf_model, 
    rf_params, 
    scoring='neg_root_mean_squared_error',
    n_jobs=-1, 
    n_iter=3, 
    cv=cv, 
    verbose=5, 
    random_state=RANDOM_STATE
)

# %%
# %%time
rf_grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV 1/5] END ...max_depth=10, n_estimators=90;, score=-20.199 total time=   4.7s
# [CV 2/5] END ...max_depth=10, n_estimators=90;, score=-21.762 total time=   9.3s
# [CV 3/5] END ...max_depth=10, n_estimators=90;, score=-22.384 total time=  14.0s
# [CV 4/5] END ...max_depth=10, n_estimators=90;, score=-21.481 total time=  19.0s
# [CV 5/5] END ...max_depth=10, n_estimators=90;, score=-29.714 total time=  23.5s
# [CV 1/5] END ...max_depth=15, n_estimators=60;, score=-20.174 total time=   3.6s
# [CV 2/5] END ...max_depth=15, n_estimators=60;, score=-21.653 total time=   7.8s
# [CV 3/5] END ...max_depth=15, n_estimators=60;, score=-22.085 total time=  12.0s
# [CV 4/5] END ...max_depth=15, n_estimators=60;, score=-21.508 total time=  16.3s
# [CV 5/5] END ...max_depth=15, n_estimators=60;, score=-29.902 total time=  21.8s
# [CV 1/5] END ....max_depth=5, n_estimators=50;, score=-20.571 total time=   1.4s
# ...

# %%
rf = rf_grid.best_estimator_
rmse_cv_rf = (-1) * rf_grid.best_score_
y_pred_rf = rf.predict(X_train)
rmse_train_rf = np.sqrt(mean_squared_error(y_train, y_pred_rf))

# %%
print(f'Лучшая модель: \n {rf}')
print(f'RMSE RandomForestRegressor на кросс-валидации {rmse_cv_rf:.4f}')
print(f'RMSE RandomForestRegressor на тренировочной выборке: {rmse_train_rf:.4f}')
print('-'*50)
models.append([rf, rmse_cv_rf, rmse_train_rf])

# %% [markdown]
# ### CatBoostRegressor

# %%
X_train_np = X_train.values if hasattr(X_train, 'values') else X_train
y_train_np = y_train.values if hasattr(y_train, 'values') else y_train

# %%
catboost_model = CatBoostRegressor(random_state=RANDOM_STATE, verbose=False)

# %%
# %%time
catboost_model.fit(X_train_np, y_train_np)

# %%
catboost_scores = cross_val_score(
    catboost_model, 
    X_train_np, 
    y_train_np, 
    cv=cv, 
    n_jobs=-1, 
    scoring='neg_root_mean_squared_error'
)

# %%
cv_score_catboost = np.mean(catboost_scores)
rmse_cv_catboost = (-1) * cv_score_catboost
y_pred_catboost = catboost_model.predict(X_train_np)
rmse_train_catboost = np.sqrt(mean_squared_error(y_train, y_pred_catboost))

# %%
print(f'RMSE CatBoost на кросс-валидации: {rmse_cv_catboost:.4f}')
print(f'RMSE CatBoost на тренировочной выборке: {rmse_train_catboost:.4f}')
print('-'*50)
models.append([catboost_model, rmse_cv_catboost, rmse_train_catboost])

# %% [markdown]
# ### Анализ моделей

# %%
models_analysis = pd.DataFrame(models, columns=['model', 'RMSE_cv', 'RMSE_train'])

models_analysis['Модель'] = models_analysis['model'].apply(
    lambda x: 'CatBoost' if isinstance(x, CatBoostRegressor) else
              'RandomForest' if isinstance(x, RandomForestRegressor) else
              'LinearRegression'
)

models_times = {
    'LinearRegression': 0.96,
    'RandomForest': 177.0,
    'CatBoost': 39.6
}
models_analysis['Время_обучения'] = models_analysis['Модель'].map(models_times)
models_analysis['Коэфф_переобучения'] = models_analysis['RMSE_train'] / models_analysis['RMSE_cv']
models_sorted = models_analysis.sort_values('RMSE_cv')

# %%
result_table = models_sorted[['Модель', 'RMSE_cv', 'RMSE_train', 'Коэфф_переобучения', 'Время_обучения']]
result_table.columns = ['Модель', 'RMSE (CV)', 'RMSE (обучение)', 'Устойчивость модели', 'Время обучения (сек)']
print(result_table.to_string(index=False, float_format=lambda x: f"{x:.4f}"))

# %% [markdown]
# Исходя из коэфф. устойчивости выбираем модель LinearRegression

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# Молодец, что пробуешь разные модели в этом шаге)
# </div>

# %% [markdown]
# ## Тестирование

# %%
y_pred = lin_reg.predict(X_test)
rmse_test = np.sqrt(mean_squared_error(y_test, y_pred))
print(f'RMSE лучшей модели на тестовой выборке: {rmse_test:.4f}')

# %%
def results(target, pred, rmse):
    result = target.to_frame().reset_index()
    result['prediction'] = pd.Series(pred)
    result.set_index('datetime', inplace=True)
    
    plt.figure(figsize=(12, 6))
    result[[target.name, 'prediction']].plot(style=['-', '--'])
    plt.title('Сравнение фактических и предсказанных значений')
    plt.ylabel('Количество заказов')
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.legend(['Фактические', 'Предсказанные'])
    
    plt.annotate(f'RMSE = {rmse:.4f}', xy=(0.05, 0.95), xycoords='axes fraction', 
                fontsize=12, bbox=dict(boxstyle="round", fc="white", alpha=0.8))
    
    plt.tight_layout()
    plt.show()
    return result

# %%
results(y_test, y_pred, rmse_test)
# Out:
#                      num_orders  prediction
# datetime
# 2018-08-14 08:00:00          91   91.167677
# 2018-08-14 09:00:00         135  111.118068
# 2018-08-14 10:00:00         155  125.664625
# 2018-08-14 11:00:00         162  107.927138
# 2018-08-14 12:00:00         114  107.939945
# 2018-08-14 13:00:00          64   98.568021
# 2018-08-14 14:00:00         112   89.920512
# 2018-08-14 15:00:00         116  120.237164
# 2018-08-14 16:00:00         111  140.604308
# 2018-08-14 17:00:00         152  125.081728
# 2018-08-14 18:00:00          98   91.980344
# 2018-08-14 19:00:00         109   91.771537
# 2018-08-14 20:00:00          84   90.846437
# 2018-08-14 21:00:00         119  126.456602
# 2018-08-14 22:00:00          81   94.012865
# 2018-08-14 23:00:00         212  127.932157
# 2018-08-15 00:00:00         211  201.037408
# 2018-08-15 01:00:00          98  187.421992
# 2018-08-15 02:00:00         157  191.873591
# 2018-08-15 03:00:00         102  137.448210
# ...

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# Отлично, что  визуализированы результаты, показаны предсказанные значения лучшей модели и реальные тестовые

# %% [markdown]
# ## Выводы

# %% [markdown]
# В рамках данного исследования разработана модель прогнозирования, позволяющая предсказать спрос на услуги такси в ближайший час. Построенная модель демонстрирует точность с показателем RMSE равным 36.9510 на контрольной выборке.
#
# Проект реализован в несколько последовательных шагов:
#
# **Первичная обработка и анализ датасета**
# - проанализирован массив из 26496 зарегистрированных поездок в аэропорты
# - временной диапазон наблюдений охватывает период март-август 2018 года
# - агрегирование данных выполнено с часовой периодичностью
# - структурных аномалий и пропусков в данных не выявлено
#
# **Исследование временных закономерностей**
#
# - выявлен восходящий тренд количества поездок к концу летнего сезона
# - определена характерная суточная динамика с пиком активности в полночь
# - установлен дневной минимум заказов около 6 часов утра
# - отмечен умеренный рост числа поездок в вечерние часы (после 16:00)
#
# **Сравнительный анализ алгоритмов моделирования**
# - испытаны различные подходы: линейное моделирование, случайный лес и градиентный бустинг
# - соотношение данных для обучения и проверки выбрано 90% к 10%
# - по совокупности факторов предпочтение отдано линейной регрессии
# - оптимальная модель обеспечивает баланс между точностью и вычислительной эффективностью
#
# **Валидация итогового решения**
# - проверка на независимой тестовой выборке подтвердила стабильность модели
# - достигнутая точность удовлетворяет требованиям, установленным заказчиком
# - графическое сопоставление прогнозов с реальными значениями подтверждает адекватность модели
#
# Созданная система прогнозирования представляет собой эффективный инструмент для планирования ресурсов такси-сервиса. Простота реализованного решения обеспечивает его прозрачность и потенциальную масштабируемость при дальнейшем развитии проекта.

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
#
# <h2> Итоговый комментарий ревьюера <a class="tocSkip"> </h2>
#
# У меня сложилось отличное общее впечатление о проекте, тебе удалось неплохо справиться с этим проектом. Молодец! Подготовлены данные для анализа, изучен каждый параметр. Все красиво визуализировано, построено несколько моделей регрессии и оценено их качество. Осмысленная аналитика и дельная модельная работа - многое удалось как надо)
#
# Отмечу отдельные положительные моменты проекта🙂:
#
# - в ходе проекта встречались функции, помогающие избавиться от дублирования кода;
# - много красивых визуализаций в проекте и хорошая интерпретация;
# - при обучении моделей использована валидация и поиск гиперпараметров.
#
# Принимаю работу)
#
# Если хочешь лучше разобраться в теме, то могу посоветовать тебе:
#
# Полезная лекция про временные ряды: https://www.youtube.com/watch?v=u433nrxdf5k
#
# Б.Б. Демешев - временные ряды https://disk.yandex.ru/i/LiDHB-B3A6Lz5A
#
# Базовое применение ARIMA - https://colab.research.google.com/drive/17RnG91Eq8JBKyxToNzvCvjibfxum-oPj?usp=sharing
#
# Канторович - Анализ временных рядов https://yadi.sk/i/IOkUOS3hTXf3gg
# https://facebook.github.io/prophet/
#
# https://facebook.github.io/prophet/docs/quick_start.html#python-api
#
# https://nbviewer.jupyter.org/github/miptgirl/habra_materials/blob/master/prophet/habra_data.ipynb
#
#
#
# В этом проекте были отработаны все моменты. Если у тебя остались вопросы, то можно обратиться ко мне через куратора или напрямую адресовать вопросы преподавателю в тред.
#
# Успехов тебе в следующем спринте!
#
# Рад был помочь тебе)
#
# **Буду очень благодарен, если ты поставишь мне положительную оценку за проект в форме на странице курса, это важно для меня. Достаточно поставить оценку, а комментарий можешь написать по желанию:)**
#
# </div>

# %% [markdown]
# ## Чек-лист проверки

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [ ]  Весь код выполняется без ошибок
# - [ ]  Ячейки с кодом расположены в порядке исполнения
# - [ ]  Данные загружены и подготовлены
# - [ ]  Данные проанализированы
# - [ ]  Модель обучена, гиперпараметры подобраны
# - [ ]  Качество моделей проверено, выводы сделаны
# - [ ]  Значение *RMSE* на тестовой выборке не больше 48
